# %%
import yfinance as yf
import pandas as pd
from yahooquery import Ticker
from itertools import islice

# %%
tickers = ["AAPL","TSLA","MSFT","NVDA"] 
for i in tickers:
    ticker = yf.Ticker(i)
    news = ticker.news
    pd.DataFrame(news)
    # news.to_csv(f"../data/raw_{i}_stock_news_data.csv")
    print(news.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 7
#       5 pd.DataFrame(news)
#       6 # news.to_csv(f"../data/raw_{i}_stock_news_data.csv")
# ----> 7 print(news.head())
#
# AttributeError: 'list' object has no attribute 'head'

# %%
ticker = yf.Ticker("AAPL")
news = ticker.news
news
# Out:
# [{'id': '29002f3a-2305-331a-8500-2c55e7097c0f',
#   'content': {'id': '29002f3a-2305-331a-8500-2c55e7097c0f',
#    'contentType': 'STORY',
#    'title': 'Layoffs and a top exec out: what GM pullback on EVs means for you',
#    'description': '',
#    'summary': "General Motors recently took its biggest step yet to address a slowing electric car industry, and it's not a minor one. GM has halted battery manufacturing in Ohio and Tennessee and reduced one of three shifts at its Detroit EV factory, resulting in the loss of approximately 1,750 jobs or temporary ...",
#    'pubDate': '2025-11-01T17:33:00Z',
#    'displayTime': '2025-11-01T17:33:00Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/thestreet_881/5ba36d1f7acde40f921d72333b48b3cd',
#     'originalWidth': 1200,
#     'originalHeight': 800,
#     'caption': '<em>General Motors is recalibrating its electric vehicle strategy amid shifting demand and internal changes.</em>',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/wnnDChpf3odhZE6Vb73i7w--~B/aD04MDA7dz0xMjAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/thestreet_881/5ba36d1f7acde40f921d72333b48b3cd',
#       'width': 1200,
#       'height': 800,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/FwFai95Yt2dYznBWixQi_w--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/thestreet_881/5ba36d1f7acde40f921d72333b48b3cd',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'TheStreet',
#     'url': 'https://www.thestreet.com/'},
#    'canonicalUrl': {'url': 'https://www.thestreet.com/automotive/layoffs-and-a-top-exec-out-what-gm-pullback-on-evs-means-for-you',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/layoffs-top-exec-gm-pullback-173300333.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '684c930d-1475-3adc-b013-ae604c056ebc',
#   'content': {'id': '684c930d-1475-3adc-b013-ae604c056ebc',
#    'contentType': 'STORY',
#    'title': "AI Stocks Face 'Show Me' Moment. Why Amazon, Google Advanced But Meta, Microsoft Sold Off.",
#    'description': '',
#    'summary': 'Amid hype over artificial intelligence, the best AI stocks generate revenue or get a strategic edge from the fast evolving technology.',
#    'pubDate': '2025-11-01T14:15:23Z',
#    'displayTime': '2025-11-01T14:15:23Z',
#    'isHosted': False,
#    'bypassModal': False,
#    'previewUrl': 'https://finance.yahoo.com/m/684c930d-1475-3adc-b013-ae604c056ebc/ai-stocks-face-show-me-.html',
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/ibd.com/d7cf9ddd4d7e16b4173298be6f3ba2a3',
#     'originalWidth': 1000,
#     'originalHeight': 565,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/vm6FVjWkOuw1cZ7OX4Tyxw--~B/aD01NjU7dz0xMDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/d7cf9ddd4d7e16b4173298be6f3ba2a3',
#       'width': 1000,
#       'height': 565,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/lNWbO7ZCcoH85acWTw0D9A--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/ibd.com/d7cf9ddd4d7e16b4173298be6f3ba2a3',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': "Investor's Business Daily",
#     'url': 'http://www.investors.com/'},
#    'canonicalUrl': {'url': 'https://www.investors.com/news/technology/artificial-intelligence-stocks/?src=A00220&yptr=yahoo',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': None,
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '8f87c358-592c-307e-bfb2-34e6a303cba9',
#   'content': {'id': '8f87c358-592c-307e-bfb2-34e6a303cba9',
#    'contentType': 'STORY',
#    'title': 'Berkshire profit rises, cash soars to record',
#    'description': '',
#    'summary': 'Berkshire Hathaway on Saturday reported a 34% increase in quarterly operating profit, helped by improved underwriting in its insurance operations, in its last financial report before Warren Buffett bows out as chief executive.',
#    'pubDate': '2025-11-01T14:02:22Z',
#    'displayTime': '2025-11-01T14:02:22Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/cnn_business_articles_218/c9586418f42440d37b1c5fc87fa47049',
#     'originalWidth': 960,
#     'originalHeight': 540,
#     'caption': "Berkshire Hathaway Chairman Warren Buffett attends the Berkshire Hathaway Inc annual shareholders' meeting in Omaha, Nebraska, on May 3, 2024. - Scott Morgan/Reuters",
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/UNjD00EuDIYcu1ecbFGvTw--~B/aD01NDA7dz05NjA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/cnn_business_articles_218/c9586418f42440d37b1c5fc87fa47049',
#       'width': 960,
#       'height': 540,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/vFBTikhP9a.yPSf0l1pvMg--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/cnn_business_articles_218/c9586418f42440d37b1c5fc87fa47049',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'CNN Business',
#     'url': 'https://www.cnn.com/business'},
#    'canonicalUrl': {'url': 'https://www.cnn.com/2025/11/01/business/berkshire-hathaway-profits-buffett',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/berkshire-profit-rises-cash-soars-130857124.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '9dcd850b-2ad0-3deb-8a67-b0eb3c93db96',
#   'content': {'id': '9dcd850b-2ad0-3deb-8a67-b0eb3c93db96',
#    'contentType': 'STORY',
#    'title': 'Magnificent Seven’s reign rolls on as Powell puts chill on rate-cut hopes',
#    'description': '',
#    'summary': 'Nvidia, Microsoft, Apple, Amazon, Alphabet, Meta Platforms and Tesla now boast a combined market value north of $22 trillion.',
#    'pubDate': '2025-11-01T11:02:51Z',
#    'displayTime': '2025-11-01T11:02:51Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/detroit-free-press/4455f67c54a5a5ece7f4f8877893ddbd',
#     'originalWidth': 1920,
#     'originalHeight': 1080,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/Ih2OozbK4Km3XumKVZZfIA--~B/aD0xMDgwO3c9MTkyMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/detroit-free-press/4455f67c54a5a5ece7f4f8877893ddbd',
#       'width': 1920,
#       'height': 1080,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/d21ej26da2e7T57NBJgiiw--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/detroit-free-press/4455f67c54a5a5ece7f4f8877893ddbd',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Detroit Free Press',
#     'url': 'https://www.freep.com'},
#    'canonicalUrl': {'url': 'https://www.freep.com/story/money/business/2025/11/01/magnificent-seven-powell-rate-cut/87013250007/',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/magnificent-seven-reign-rolls-powell-110251362.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '5d6679c7-f947-42e8-98af-8d5e9dfa4e1d',
#   'content': {'id': '5d6679c7-f947-42e8-98af-8d5e9dfa4e1d',
#    'contentType': 'STORY',
#    'title': 'My laundrette closed early so I set up a £27m global laundry service',
#    'description': '',
#    'summary': 'Deyan Dimitrov is CEO and founder at Laundryheap, the London-founded on-demand laundry behemoth which is raking in millions.',
#    'pubDate': '2025-11-01T06:00:31Z',
#    'displayTime': '2025-11-01T06:00:31Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://s.yimg.com/os/creatr-uploaded-images/2025-10/0f35d210-b572-11f0-9b7f-860a4530671c',
#     'originalWidth': 1950,
#     'originalHeight': 1249,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/F8uYsYeukxeUl.UoUGTIUw--~B/aD0xMjQ5O3c9MTk1MDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2025-10/0f35d210-b572-11f0-9b7f-860a4530671c',
#       'width': 1950,
#       'height': 1249,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/mJDwrlM30qZWl.qGCNhBGA--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2025-10/0f35d210-b572-11f0-9b7f-860a4530671c',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Yahoo Finance UK',
#     'url': 'http://uk.finance.yahoo.com/'},
#    'canonicalUrl': {'url': 'https://uk.finance.yahoo.com/news/drycleaning-service-laundryheap-060031152.html',
#     'site': 'finance',
#     'region': 'GB',
#     'lang': 'en-GB'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/drycleaning-service-laundryheap-060031152.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': 'addd5428-de8e-30d6-bcaf-3de6b149e43b',
#   'content': {'id': 'addd5428-de8e-30d6-bcaf-3de6b149e43b',
#    'contentType': 'STORY',
#    'title': 'Apple (AAPL): Net Profit Margin Decline to 24.3% Challenges Bullish Narratives',
#    'description': '',
#    'summary': 'Apple (AAPL) is forecasting annual earnings growth of 8.16% and revenue growth of 5.7%, both trailing the US market averages. Over the past five years, the company has delivered 5.8% annual earnings growth, but its net profit margin has narrowed to 24.3% from 26.4% a year ago. While shares trade at $270.37, a premium to the estimated fair value of $231.08, investors are weighing the ongoing growth with the reality of declining profitability. See our full analysis for Apple. The real test is...',
#    'pubDate': '2025-11-01T02:19:10Z',
#    'displayTime': '2025-11-01T02:19:10Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/simply_wall_st__316/69084628647944e382f8e555f97913e8',
#     'originalWidth': 1194,
#     'originalHeight': 432,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/fBnY8upz5XxbZDDWlufZ9w--~B/aD00MzI7dz0xMTk0O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/simply_wall_st__316/69084628647944e382f8e555f97913e8',
#       'width': 1194,
#       'height': 432,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/bU5AIomYRBg3WBNqAswADg--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/simply_wall_st__316/69084628647944e382f8e555f97913e8',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Simply Wall St.',
#     'url': 'https://simplywall.st/'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/apple-aapl-net-profit-margin-021910677.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/apple-aapl-net-profit-margin-021910677.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': 'ed110364-fe80-3d13-a7f5-59dfcd7154f3',
#   'content': {'id': 'ed110364-fe80-3d13-a7f5-59dfcd7154f3',
#    'contentType': 'STORY',
#    'title': 'How Tim Cook Evaded Disaster at Apple This Year',
#    'description': '',
#    'summary': 'The CEO was facing risks from Trump’s tariffs, Google litigation and the AI craze. He turned to his playbook and now the iPhone maker is worth $4 trillion.',
#    'pubDate': '2025-11-01T00:00:00Z',
#    'displayTime': '2025-11-01T00:00:00Z',
#    'isHosted': False,
#    'bypassModal': False,
#    'previewUrl': 'https://finance.yahoo.com/m/ed110364-fe80-3d13-a7f5-59dfcd7154f3/how-tim-cook-evaded-disaster.html',
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/wsj.com/837d5f829abe46216d49cbc8fe0d90b1',
#     'originalWidth': 1280,
#     'originalHeight': 640,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/S5xE6PCtI7XkGt4l8Ywb7A--~B/aD02NDA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/wsj.com/837d5f829abe46216d49cbc8fe0d90b1',
#       'width': 1280,
#       'height': 640,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/F3B56r3vWu_ZVV3vJA1m9g--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/wsj.com/837d5f829abe46216d49cbc8fe0d90b1',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'The Wall Street Journal',
#     'url': 'http://www.wsj.com/'},
#    'canonicalUrl': {'url': 'https://www.wsj.com/tech/apple-2025-tim-cook-36af914a?siteid=yhoof2&yptr=yahoo',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': None,
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '6db6860c-7fc6-309d-9b56-85fb90941668',
#   'content': {'id': '6db6860c-7fc6-309d-9b56-85fb90941668',
#    'contentType': 'STORY',
#    'title': 'Closing Bell Movers: Amazon soars to all-time highs on earnings',
#    'description': '',
#    'summary': 'In the opening hour of the evening session, U.S. equity futures are notably higher, with S&P 500 up 0.5% and Nasdaq 100 contracts up 1.0%. In commodities, WTI Crude Oil is little changed just above $60 per barrel while precious metals are stronger for the 3rd day in a row – Gold is above $4,040 and Silver is approaching $49 per ounce. A strong slate of quarterly Tech results are helping stock futures restore positive sentiment in the segment that was wounded on Thursday by more dubious results o',
#    'pubDate': '2025-10-31T23:35:38Z',
#    'displayTime': '2025-10-31T23:35:38Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/tipranks_452/c4f6c07e08d4829fbea65fa26099a197',
#     'originalWidth': 192,
#     'originalHeight': 192,
#     'caption': 'https://www.tipranks.com/news/the-fly/closing-bell-movers-amazon-soars-to-all-time-highs-on-earnings-thefly',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/CelDdPDqWVkcG2SiBC__kg--~B/aD0xOTI7dz0xOTI7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/tipranks_452/c4f6c07e08d4829fbea65fa26099a197',
#       'width': 192,
#       'height': 192,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/Qv5uHFeHO0LaVjiqA54n8Q--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/tipranks_452/c4f6c07e08d4829fbea65fa26099a197',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'TipRanks', 'url': 'https://www.tipranks.com/'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/closing-bell-movers-amazon-soars-233538498.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/closing-bell-movers-amazon-soars-233538498.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '63b9fcae-543a-328e-a4f2-73eff8e3c853',
#   'content': {'id': '63b9fcae-543a-328e-a4f2-73eff8e3c853',
#    'contentType': 'STORY',
#    'title': 'One tech giant outdid its Mag 7 cohort this week, with analysts rushing to hike their price targets',
#    'description': '',
#    'summary': 'The Week in Stocks: A fashion retailer looks good, Cameco on a tear and analyst price hikes on TSX majors',
#    'pubDate': '2025-10-31T22:40:44Z',
#    'displayTime': '2025-10-31T22:40:44Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/financial_post_articles_610/ca7da69dac80ab334ec60865dd80196d',
#     'originalWidth': 1280,
#     'originalHeight': 960,
#     'caption': 'amazon-ggs1031',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/SccovETAqHKzGuhRLHqizg--~B/aD05NjA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/financial_post_articles_610/ca7da69dac80ab334ec60865dd80196d',
#       'width': 1280,
#       'height': 960,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/aTRSuPkdof8v_JT8lDRjUQ--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/financial_post_articles_610/ca7da69dac80ab334ec60865dd80196d',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Financial Post',
#     'url': 'https://financialpost.com/'},
#    'canonicalUrl': {'url': 'https://ca.finance.yahoo.com/news/one-tech-giant-outdid-mag-224044158.html',
#     'site': 'finance',
#     'region': 'CA',
#     'lang': 'en-CA'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/one-tech-giant-outdid-mag-224044158.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': 'c56c6928-c549-3d23-81f5-aeac70568e0a',
#   'content': {'id': 'c56c6928-c549-3d23-81f5-aeac70568e0a',
#    'contentType': 'STORY',
#    'title': 'Heard on the Street Recap: Market Streak',
#    'description': '',
#    'summary': 'What Happened in Markets Today Amazon soared. The e-commerce and cloud-computing giant’s shares hit a record high and ended the day 9.6% higher. While the company’s quarterly revenue outlook Thursday came short of Wall Street’s expectations, stronger growth in its cloud unit pleased investors.',
#    'pubDate': '2025-10-31T21:19:01Z',
#    'displayTime': '2025-10-31T21:19:01Z',
#    'isHosted': False,
#    'bypassModal': False,
#    'previewUrl': 'https://finance.yahoo.com/m/c56c6928-c549-3d23-81f5-aeac70568e0a/heard-on-the-street-recap-.html',
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/wsj.com/80a06fe548b9b77550063c3d32b4eccc',
#     'originalWidth': 1280,
#     'originalHeight': 640,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/_trP0JXL0i49aIpuzOizYg--~B/aD02NDA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/wsj.com/80a06fe548b9b77550063c3d32b4eccc',
#       'width': 1280,
#       'height': 640,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/_XdzRS.iMXGlJlQ5tG5lLg--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/wsj.com/80a06fe548b9b77550063c3d32b4eccc',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'The Wall Street Journal',
#     'url': 'http://www.wsj.com/'},
#    'canonicalUrl': {'url': 'https://www.wsj.com/livecoverage/stock-market-today-dow-sp-500-nasdaq-10-31-2025/card/heard-on-the-street-recap-market-streak-QgX7CMgK4EDDVuqVK36f?siteid=yhoof2&yptr=yahoo',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': None,
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}}]

# %%
df = pd.DataFrame(news[1])
df.drop("id", axis='columns', inplace=True)
df.head()
# Out:
#                                                        content
# id                        8c5499cc-586c-3ab9-b7fa-4b706c76e01a
# contentType                                              STORY
# title        Elon Musk wants you to know that Sam Altman go...
# description
# summary      Elon Musk and Sam Altman are still taking swip...

# %%
def get_yahoo_finance_news(ticker_symbol, limit=10):
    """
    Fetches recent Yahoo Finance news for a given ticker.
    Returns a pandas DataFrame with title, publisher, and URL.
    """
    ticker = yf.Ticker(ticker_symbol)
    news_items = ticker.news
    dex = [i for i in range(1,1)]
    

    if not news_items:
        print(f"No news found for {ticker_symbol}.")
        return pd.DataFrame()

    df = pd.DataFrame(dict(islice(news_items[0]['content'].items(), 6)) , index=dex)
    rows = []
    for i in news_items:
        rows.append(dict(islice(i['content'].items(), 6)))

    df = pd.concat([df, pd.DataFrame(rows)], ignore_index=True)
    
    # Convert publish time from timestamp to readable date
    # df['providerPublishTime'] = pd.to_datetime(df['providerPublishTime'], unit='s')
    
    return df

# %%
AAPL_news_df = get_yahoo_finance_news("AAPL", limit=5)
AAPL_news_df.drop(['id', 'contentType', 'description'],axis='columns', inplace=True)
AAPL_news_df
# Out:
#                                                title  \
# 0  Layoffs and a top exec out: what GM pullback o...
# 1  AI Stocks Face 'Show Me' Moment. Why Amazon, G...
# 2       Berkshire profit rises, cash soars to record
# 3  Magnificent Seven’s reign rolls on as Powell p...
# 4  My laundrette closed early so I set up a £27m ...
# 5  Apple (AAPL): Net Profit Margin Decline to 24....
# 6    How Tim Cook Evaded Disaster at Apple This Year
# 7  Closing Bell Movers: Amazon soars to all-time ...
# 8  One tech giant outdid its Mag 7 cohort this we...
# 9           Heard on the Street Recap: Market Streak
#
#                                              summary               pubDate
# 0  General Motors recently took its biggest step ...  2025-11-01T17:33:00Z
# 1  Amid hype over artificial intelligence, the be...  2025-11-01T14:15:23Z
# 2  Berkshire Hathaway on Saturday reported a 34% ...  2025-11-01T14:02:22Z
# 3  Nvidia, Microsoft, Apple, Amazon, Alphabet, Me...  2025-11-01T11:02:51Z
# 4  Deyan Dimitrov is CEO and founder at Laundryhe...  2025-11-01T06:00:31Z
# 5  Apple (AAPL) is forecasting annual earnings gr...  2025-11-01T02:19:10Z
# 6  The CEO was facing risks from Trump’s tariffs,...  2025-11-01T00:00:00Z
# 7  In the opening hour of the evening session, U....  2025-10-31T23:35:38Z
# 8  The Week in Stocks: A fashion retailer looks g...  2025-10-31T22:40:44Z
# 9  What Happened in Markets Today Amazon soared. ...  2025-10-31T21:19:01Z

# %%
AAPL_news_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    10 non-null     object
#  1   summary  10 non-null     object
#  2   pubDate  10 non-null     object
# dtypes: object(3)
# memory usage: 372.0+ bytes

# %%
count = 0
for i in news:
    count += 1
    print(count)
    print("------------------------------------")
    # print(i["content"].keys())
    print(dict(islice(i['content'].items(), 7)))
    # print(i["content"]['id'])
    # print(i["content"]['contentType'])
    # print(i["content"]['title'])
    # print(i["content"]['description'])
    # print(i["content"]['summary'])
    # print(i["content"]['pubDate'])
    # print(i["content"]['displayTime'])
    # df = pd.DataFrame(i["content"])
    # print(df.head())
    # print(i)
    print("------------------------------------")
    # print(i.keys())
# Out:
# 1
# ------------------------------------
# {'id': '29002f3a-2305-331a-8500-2c55e7097c0f', 'contentType': 'STORY', 'title': 'Layoffs and a top exec out: what GM pullback on EVs means for you', 'description': '', 'summary': "General Motors recently took its biggest step yet to address a slowing electric car industry, and it's not a minor one. GM has halted battery manufacturing in Ohio and Tennessee and reduced one of three shifts at its Detroit EV factory, resulting in the loss of approximately 1,750 jobs or temporary ...", 'pubDate': '2025-11-01T17:33:00Z', 'displayTime': '2025-11-01T17:33:00Z'}
# ------------------------------------
# 2
# ------------------------------------
# {'id': '684c930d-1475-3adc-b013-ae604c056ebc', 'contentType': 'STORY', 'title': "AI Stocks Face 'Show Me' Moment. Why Amazon, Google Advanced But Meta, Microsoft Sold Off.", 'description': '', 'summary': 'Amid hype over artificial intelligence, the best AI stocks generate revenue or get a strategic edge from the fast evolving technology.', 'pubDate': '2025-11-01T14:15:23Z', 'displayTime': '2025-11-01T14:15:23Z'}
# ------------------------------------
# 3
# ------------------------------------
# {'id': '8f87c358-592c-307e-bfb2-34e6a303cba9', 'contentType': 'STORY', 'title': 'Berkshire profit rises, cash soars to record', 'description': '', 'summary': 'Berkshire Hathaway on Saturday reported a 34% increase in quarterly operating profit, helped by improved underwriting in its insurance operations, in its last financial report before Warren Buffett bows out as chief executive.', 'pubDate': '2025-11-01T14:02:22Z', 'displayTime': '2025-11-01T14:02:22Z'}
# ------------------------------------
# 4
# ------------------------------------
# {'id': '9dcd850b-2ad0-3deb-8a67-b0eb3c93db96', 'contentType': 'STORY', 'title': 'Magnificent Seven’s reign rolls on as Powell puts chill on rate-cut hopes', 'description': '', 'summary': 'Nvidia, Microsoft, Apple, Amazon, Alphabet, Meta Platforms and Tesla now boast a combined market value north of $22 trillion.', 'pubDate': '2025-11-01T11:02:51Z', 'displayTime': '2025-11-01T11:02:51Z'}
# ------------------------------------
# 5
# ------------------------------------
# {'id': '5d6679c7-f947-42e8-98af-8d5e9dfa4e1d', 'contentType': 'STORY', 'title': 'My laundrette closed early so I set up a £27m global laundry service', 'description': '', 'summary': 'Deyan Dimitrov is CEO and founder at Laundryheap, the London-founded on-demand laundry behemoth which is raking in millions.', 'pubDate': '2025-11-01T06:00:31Z', 'displayTime': '2025-11-01T06:00:31Z'}
# ------------------------------------
# 6
# ------------------------------------
# {'id': 'addd5428-de8e-30d6-bcaf-3de6b149e43b', 'contentType': 'STORY', 'title': 'Apple (AAPL): Net Profit Margin Decline to 24.3% Challenges Bullish Narratives', 'description': '', 'summary': 'Apple (AAPL) is forecasting annual earnings growth of 8.16% and revenue growth of 5.7%, both trailing the US market averages. Over the past five years, the company has delivered 5.8% annual earnings growth, but its net profit margin has narrowed to 24.3% from 26.4% a year ago. While shares trade at $270.37, a premium to the estimated fair value of $231.08, investors are weighing the ongoing growth with the reality of declining profitability. See our full analysis for Apple. The real test is...', 'pubDate': '2025-11-01T02:19:10Z', 'displayTime': '2025-11-01T02:19:10Z'}
# ------------------------------------
# 7
# ------------------------------------
# {'id': 'ed110364-fe80-3d13-a7f5-59dfcd7154f3', 'contentType': 'STORY', 'title': 'How Tim Cook Evaded Disaster at Apple This Year', 'description': '', 'summary': 'The CEO was facing risks from Trump’s tariffs, Google litigation and the AI craze. He turned to his playbook and now the iPhone maker is worth $4 trillion.', 'pubDate': '2025-11-01T00:00:00Z', 'displayTime': '2025-11-01T00:00:00Z'}
# ------------------------------------
# 8
# ------------------------------------
# {'id': '6db6860c-7fc6-309d-9b56-85fb90941668', 'contentType': 'STORY', 'title': 'Closing Bell Movers: Amazon soars to all-time highs on earnings', 'description': '', 'summary': 'In the opening hour of the evening session, U.S. equity futures are notably higher, with S&P 500 up 0.5% and Nasdaq 100 contracts up 1.0%. In commodities, WTI Crude Oil is little changed just above $60 per barrel while precious metals are stronger for the 3rd day in a row – Gold is above $4,040 and Silver is approaching $49 per ounce. A strong slate of quarterly Tech results are helping stock futures restore positive sentiment in the segment that was wounded on Thursday by more dubious results o', 'pubDate': '2025-10-31T23:35:38Z', 'displayTime': '2025-10-31T23:35:38Z'}
# ------------------------------------
# 9
# ------------------------------------
# {'id': '63b9fcae-543a-328e-a4f2-73eff8e3c853', 'contentType': 'STORY', 'title': 'One tech giant outdid its Mag 7 cohort this week, with analysts rushing to hike their price targets', 'description': '', 'summary': 'The Week in Stocks: A fashion retailer looks good, Cameco on a tear and analyst price hikes on TSX majors', 'pubDate': '2025-10-31T22:40:44Z', 'displayTime': '2025-10-31T22:40:44Z'}
# ------------------------------------
# 10
# ------------------------------------
# {'id': 'c56c6928-c549-3d23-81f5-aeac70568e0a', 'contentType': 'STORY', 'title': 'Heard on the Street Recap: Market Streak', 'description': '', 'summary': 'What Happened in Markets Today Amazon soared. The e-commerce and cloud-computing giant’s shares hit a record high and ended the day 9.6% higher. While the company’s quarterly revenue outlook Thursday came short of Wall Street’s expectations, stronger growth in its cloud unit pleased investors.', 'pubDate': '2025-10-31T21:19:01Z', 'displayTime': '2025-10-31T21:19:01Z'}
# ------------------------------------

# %%
import requests, time

url = "https://api.gdeltproject.org/api/v2/doc/doc?query=apple&maxrecords=100&format=json"
headers = {"User-Agent": "Mozilla/5.0"}
time.sleep(2)

response = requests.get(url, headers=headers)
print(response.status_code)
# Out:
# 200

# %%
data = response.json()['articles']
df = pd.DataFrame(data)[['seendate','title','url','seendate','sourcecountry','language']]
df
# Out:
#             seendate                                              title  \
# 0   20250819T103000Z  30+ открыток и картинок с поздравлениями с Ябл...
# 1   20250822T163000Z  Apple One pricing : How much you save with bun...
# 2   20250821T214500Z  Apple One just got harder to resist , with mor...
# 3   20250820T003000Z  You Might Be Able To Unlock Future Apple Watch...
# 4   20250817T123000Z  Cách chọn táo đỏ ngon , bổ dưỡng ai cũng cần biết
# ..               ...                                                ...
# 95  20251014T230000Z  Eddy Cue explains why Apple TV dropped Plus , ...
# 96  20251031T010000Z                   库克确认 ， 苹果牌 AI  将整合更多第三方供应商|库克|AI
# 97  20251014T014500Z          Apple TV+ is dead . Long live Apple TV !
# 98  20251020T031500Z                                       特努斯能让苹果再次伟大吗
# 99  20251031T004500Z                      苹果最新季度大中华区收入下滑 ， 管理层预计下季度恢复增长
#
#                                                   url          seendate  \
# 0   https://7days.ru/lifestyle/family/yablochnyy-s...  20250819T103000Z
# 1   https://www.cultofmac.com/news/apple-one-subsc...  20250822T163000Z
# 2   https://9to5mac.com/2025/08/21/apple-one-just-...  20250821T214500Z
# 3   https://www.bgr.com/1944930/apple-watch-touch-...  20250820T003000Z
# 4   https://baomoi.com/cach-chon-tao-do-ngon-bo-du...  20250817T123000Z
# ..                                                ...               ...
# 95  https://9to5mac.com/2025/10/14/eddy-cue-explai...  20251014T230000Z
# 96  https://finance.sina.com.cn/tech/digi/2025-10-...  20251031T010000Z
# 97  https://www.digitaltrends.com/movies/apple-tv-...  20251014T014500Z
# 98  https://www.163.com/dy/article/KCAC45F90511BCO...  20251020T031500Z
# 99          https://www.yicai.com/news/102888992.html  20251031T004500Z
#
#     sourcecountry    language
# 0          Russia     Russian
# 1   United States     English
# 2   United States     English
# 3   United States     English
# 4         Vietnam  Vietnamese
# ..            ...         ...
# 95  United States     English
# 96          China     Chinese
# 97  United States     English
# 98          China     Chinese
# 99          China     Chinese
#
# [100 rows x 6 columns]

# %%
import http.client, urllib.parse

conn = http.client.HTTPSConnection('api.marketaux.com')

params = urllib.parse.urlencode({
    'api_token': 'LAL4kTs0w27IGZyBljddPifwasQboGFE4haatauY',
    'symbols': 'AAPL,TSLA,MSFT,NVDA',
    'limit': 50,
    })

conn.request('GET', '/v1/news/all?{}'.format(params))

res = conn.getresponse()
data = res.read()

print(data.decode('utf-8'))
# Out:
# {"warnings":["limit is higher than your plan allows"],"meta":{"found":281447,"returned":3,"limit":3,"page":1},"data":[{"uuid":"071fb9b9-3aae-466f-8285-0043924ca6ee","title":"Microsoft (MSFT)’s Traditional Software “Was Extraordinary,” Says Jim Cramer","description":"We recently published 10 Stocks on Jim Cramer’s Radar. Microsoft Corporation (NASDAQ:MSFT) is one of the stocks Jim Cramer recently discussed. Microsoft Corporation (NASDAQ:MSFT) latest earnings report saw its shares drop by 4% even though the firm’s $77.67 billion in revenue and $3.72 in earnings per share beat analyst estimates, and its cloud computing revenue […]","keywords":"Microsoft Corporation, Jim Cramer, Satya Nadella, Amy Hood, earnings report","snippet":"We recently published 10 Stocks on Jim Cramer’s Radar. Microsoft Corporation (NASDAQ:MSFT) is one of the stocks Jim Cramer recently discussed.\n\nMicrosoft Corp...","url":"https:\/\/finance.yahoo.com\/news\/microsoft-msft-traditional-software-extraordinary-193055649.html","image_url":"https:\/\/media.zenfs.com\/en\/insidermonkey.com\/b5fca8d1106b22f327b2338c10eb2ab1","language":"en","published_at":"2025-11-01T19:30:55.000000Z","source":"finance.yahoo.com","relevance_score":null,"entities":[{"symbol":"MSF.BR","name":"Microsoft Corporation","exchange":null,"exchange_long":null,"country":"be","type":"equity","industry":"Technology","match_score":37.11631,"sentiment_score":0.148733,"highlights":[{"highlight":"<em>Microsoft<\/em> <em>Corporation<\/em> [+321 characters]","sentiment":0.3182,"highlighted_in":"main_text"},{"highlight":"The <em>Microsoft<\/em> <em>Corporation<\/[+329 characters]","sentiment":0.128,"highlighted_in":"main_text"},{"highlight":"<em>Microsoft<\/em> (MSFT)’s Traditional Software “Was Extraordinary,” Says Jim Cramer","sentiment":0,"highlighted_in":"title"}]},{"symbol":"MSFT","name":"Microsoft Corporation","exchange":null,"exchange_long":null,"country":"us","type":"equity","industry":"Technology","match_score":52.41514,"sentiment_score":0.148733,"highlights":[{"highlight":"<em>Microsoft<\/em> <em>Corporation<\/em> [+339 characters]","sentiment":0.3182,"highlighted_in":"main_text"},{"highlight":"The <em>Microsoft<\/em> <em>Corporation<\/[+338 characters]","sentiment":0.128,"highlighted_in":"main_text"},{"highlight":"<em>Microsoft<\/em> (MSFT)’s Traditional Software “Was Extraordinary,” Says Jim Cramer","sentiment":0,"highlighted_in":"title"}]},{"symbol":"MSFT.SN","name":"Microsoft Corporation","exchange":null,"exchange_long":null,"country":"cl","type":"equity","industry":"Technology","match_score":37.116318,"sentiment_score":0.148733,"highlights":[{"highlight":"<em>Microsoft<\/em> <em>Corporation<\/em> [+321 characters]","sentiment":0.3182,"highlighted_in":"main_text"},{"highlight":"The <em>Microsoft<\/em> <em>Corporation<\/[+329 characters]","sentiment":0.128,"highlighted_in":"main_text"},{"highlight":"<em>Microsoft<\/em> (MSFT)’s Traditional Software “Was Extraordinary,” Says Jim Cramer","sentiment":0,"highlighted_in":"title"}]},{"symbol":"MSF.DE","name":"Microsoft Corporation","exchange":null,"exchange_long":null,"country":"de","type":"equity","industry":"Technology","match_score":37.117157,"sentiment_score":0.148733,"highlights":[{"highlight":"<em>Microsoft<\/em> <em>Corporation<\/em> [+321 characters]","sentiment":0.3182,"highlighted_in":"main_text"},{"highlight":"The <em>Microsoft<\/em> <em>Corporation<\/[+329 characters]","sentiment":0.128,"highlighted_in":"main_text"},{"highlight":"<em>Microsoft<\/em> (MSFT)’s Traditional Software “Was Extraordinary,” Says Jim Cramer","sentiment":0,"highlighted_in":"title"}]}],"similar":[{"uuid":"ee97e03a-1b5b-4796-b0a4-9f1434b28332","title":"NVIDIA (NVDA) CEO Is Confident Chinese Military Won’t Use His GPUs, Says Jim Cramer","description":"We recently published 10 Stocks on Jim Cramer’s Radar. NVIDIA Corporation (NASDAQ:NVDA) is one of the stocks Jim Cramer recently discussed. NVIDIA Corporation (NASDAQ:NVDA) was in the spotlight after President T ...

# %%
import json
count = 0
json_data = json.loads(data.decode('utf-8'))
for i in json_data['data']:
    count += 1
    print(count)
    print(i)
    print("------------------------------------")
    # print(i.keys())
# Out:
# 1
# {'uuid': '071fb9b9-3aae-466f-8285-0043924ca6ee', 'title': 'Microsoft (MSFT)’s Traditional Software “Was Extraordinary,” Says Jim Cramer', 'description': 'We recently published 10 Stocks on Jim Cramer’s Radar. Microsoft Corporation (NASDAQ:MSFT) is one of the stocks Jim Cramer recently discussed. Microsoft Corporation (NASDAQ:MSFT) latest earnings report saw its shares drop by 4% even though the firm’s $77.67 billion in revenue and $3.72 in earnings per share beat analyst estimates, and its cloud computing revenue […]', 'keywords': 'Microsoft Corporation, Jim Cramer, Satya Nadella, Amy Hood, earnings report', 'snippet': 'We recently published 10 Stocks on Jim Cramer’s Radar. Microsoft Corporation (NASDAQ:MSFT) is one of the stocks Jim Cramer recently discussed.\n\nMicrosoft Corp...', 'url': 'https://finance.yahoo.com/news/microsoft-msft-traditional-software-extraordinary-193055649.html', 'image_url': 'https://media.zenfs.com/en/insidermonkey.com/b5fca8d1106b22f327b2338c10eb2ab1', 'language': 'en', 'published_at': '2025-11-01T19:30:55.000000Z', 'source': 'finance.yahoo.com', 'relevance_score': None, 'entities': [{'symbol': 'MSF.BR', 'name': 'Microsoft Corporation', 'exchange': None, 'exchange_long': None, 'country': 'be', 'type': 'equity', 'industry': 'Technology', 'match_score': 37.11631, 'sentiment_score': 0.148733, 'highlights': [{'highlight': '<em>Microsoft</em> <em>Corporation</em> [+321 characters]', 'sentiment': 0.3182, 'highlighted_in': 'main_text'}, {'highlight': 'The <em>Microsoft</em> <em>Corporation</[+329 characters]', 'sentiment': 0.128, 'highlighted_in': 'main_text'}, {'highlight': '<em>Microsoft</em> (MSFT)’s Traditional Software “Was Extraordinary,” Says Jim Cramer', 'sentiment': 0, 'highlighted_in': 'title'}]}, {'symbol': 'MSFT', 'name': 'Microsoft Corporation', 'exchange': None, 'exchange_long': None, 'country': 'us', 'type': 'equity', 'industry': 'Technology', 'match_score': 52.41514, 'sentiment_score': 0.148733, 'highlights': [{'highlight': '<em>Microsoft</em> <em>Corporation</em> [+339 characters]', 'sentiment': 0.3182, 'highlighted_in': 'main_text'}, {'highlight': 'The <em>Microsoft</em> <em>Corporation</[+338 characters]', 'sentiment': 0.128, 'highlighted_in': 'main_text'}, {'highlight': '<em>Microsoft</em> (MSFT)’s Traditional Software “Was Extraordinary,” Says Jim Cramer', 'sentiment': 0, 'highlighted_in': 'title'}]}, {'symbol': 'MSFT.SN', 'name': 'Microsoft Corporation', 'exchange': None, 'exchange_long': None, 'country': 'cl', 'type': 'equity', 'industry': 'Technology', 'match_score': 37.116318, 'sentiment_score': 0.148733, 'highlights': [{'highlight': '<em>Microsoft</em> <em>Corporation</em> [+321 characters]', 'sentiment': 0.3182, 'highlighted_in': 'main_text'}, {'highlight': 'The <em>Microsoft</em> <em>Corporation</[+329 characters]', 'sentiment': 0.128, 'highlighted_in': 'main_text'}, {'highlight': '<em>Microsoft</em> (MSFT)’s Traditional Software “Was Extraordinary,” Says Jim Cramer', 'sentiment': 0, 'highlighted_in': 'title'}]}, {'symbol': 'MSF.DE', 'name': 'Microsoft Corporation', 'exchange': None, 'exchange_long': None, 'country': 'de', 'type': 'equity', 'industry': 'Technology', 'match_score': 37.117157, 'sentiment_score': 0.148733, 'highlights': [{'highlight': '<em>Microsoft</em> <em>Corporation</em> [+321 characters]', 'sentiment': 0.3182, 'highlighted_in': 'main_text'}, {'highlight': 'The <em>Microsoft</em> <em>Corporation</[+329 characters]', 'sentiment': 0.128, 'highlighted_in': 'main_text'}, {'highlight': '<em>Microsoft</em> (MSFT)’s Traditional Software “Was Extraordinary,” Says Jim Cramer', 'sentiment': 0, 'highlighted_in': 'title'}]}], 'similar': [{'uuid': 'ee97e03a-1b5b-4796-b0a4-9f1434b28332', 'title': 'NVIDIA (NVDA) CEO Is Confident Chinese Military Won’t Use His GPUs, Says Jim Cramer', 'description': 'We recently published 10 Stocks on Jim Cramer’s Radar. NVIDIA Corporation (NASDAQ:NVDA) is one of the stocks Jim Cramer recently discussed. NVIDIA Corporation (NASDAQ:NVDA) was in t ...
# ------------------------------------
# 2
# {'uuid': '459a7a80-77e5-4f4c-830d-3dcc6e2fdac8', 'title': "Video Game CEO Says Regenerative AI Will 'Increase Employment,' Despite Job Losses In The Industry", 'description': 'Regenerative AI will create more jobs in the video game industry, Take-Two (NASDAQ:TTWO) CEO Strauss Zelnick said recently, despite the fact that thousands of animators and other behind-the-scenes workers have lost their jobs due to the technology. “It will not reduce employment, it will increase employment,” Zelnick said during a talk on Oct. 17 at The Paley Center for Media, according to media reports.. “Technology always increases productivity, which in turn increases GDP, which in turn incre', 'keywords': 'Strauss Zelnick, The Paley Center for Media, Game Developers Conference, video game industry, game developers, game development, Accredited Investors, video game, video game console', 'snippet': 'Regenerative AI will create more jobs in the video game industry, Take-Two (NASDAQ:TTWO) CEO Strauss Zelnick said recently, despite the fact that thousands of a...', 'url': 'https://finance.yahoo.com/news/video-game-ceo-says-regenerative-180129066.html', 'image_url': 'https://media.zenfs.com/en/Benzinga/11a4160e7c9b5ec872c25e100efe9579', 'language': 'en', 'published_at': '2025-11-01T18:01:29.000000Z', 'source': 'finance.yahoo.com', 'relevance_score': None, 'entities': [{'symbol': 'MSFT', 'name': 'Microsoft Corporation', 'exchange': None, 'exchange_long': None, 'country': 'us', 'type': 'equity', 'industry': 'Technology', 'match_score': 14.367173, 'sentiment_score': -0.1779, 'highlights': [{'highlight': '<em>Microsoft</em> (<em>NASDAQ:MSFT</em>[+269 characters]', 'sentiment': -0.1779, 'highlighted_in': 'main_text'}]}], 'similar': []}
# ------------------------------------
# 3
# {'uuid': '20f955ef-010a-40aa-95e4-3a4b6a6003b6', 'title': 'I Think These Are the 2 Best AI Stocks to Buy in November', 'description': "The AI infrastructure buildout has moved from speculation to reality, and two companies are positioned to capture the lion's share of spending.", 'keywords': 'Amazon Web Services, Nvidia, data centers, capital expenditure, Microsoft, infrastructure', 'snippet': 'Key Points\n\nThe AI hyperbuild is now an accounting line item, with major tech companies raising 2025 capital expenditure plans and pointing to even larger 2026 ...', 'url': 'https://finance.yahoo.com/news/think-2-best-ai-stocks-180000148.html', 'image_url': 'https://s.yimg.com/ny/api/res/1.2/KYZbSHAggjFnSLYePuMmog--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDE-/https://media.zenfs.com/en/motleyfool.com/036714c150893e08de909f9df5e112df', 'language': 'en', 'published_at': '2025-11-01T18:00:00.000000Z', 'source': 'finance.yahoo.com', 'relevance_score': None, 'entities': [{'symbol': 'GOOGL', 'name': 'Alphabet Inc.', 'exchange': None, 'exchange_long': None, 'country': 'us', 'type': 'equity', 'industry': 'Communication Services', 'match_score': 16.388449, 'sentiment_score': 0.180767, 'highlights': [{'highlight': 'When Microsoft, <em>Alphabet</em>, Meta [+303 characters]', 'sentiment': 0.5423, 'highlighted_in': 'main_text'}, {'highlight': '<em>Alphabet</em> lifted its 2025 capita[+266 characters]', 'sentiment': 0, 'highlighted_in': 'main_text'}, {'highlight': 'The hyperscalers (Amazon, Microsoft, <em[+199 characters]', 'sentiment': 0, 'highlighted_in': 'main_text'}]}, {'symbol': 'NVDA', 'name': 'NVIDIA Corporation', 'exchange': None, 'exchange_long': None, 'country': 'us', 'type': 'equity', 'industry': 'Technology', 'match_score': 27.98259, 'sentiment_score': 0.46485, 'highlights': [{'highlight': '<em>Nvidia</em> has more than $500 billi[+125 characters]', 'sentiment': -0.128, 'highlighted_in': 'main_text'}, {'highlight': 'Amazon Web Services just posted 20% grow[+239 characters]', 'sentiment': 0.8957, 'highlighted_in': 'main_text'}, {'highlight': 'Against that backdrop, I think two stock[+305 characters]', 'sentiment': 0.5574, 'highlighted_in': 'main_text'}, {'highlight': 'The chip architect sitting on half a tri[+303 characters]', 'sentiment': 0.4336, 'highlighted_in': 'main_text'}, {'highlight': '<em>Nvidia</em> benefits directly from t[+119 characters]', 'sentiment': 0.3818, 'highlighted_in': 'main_text'}, {'highlight': "The company's competitive advantage exte[+245 characters]", 'sentiment': 0.6486, 'highlighted_in': 'main_text'}]}, {'symbol': 'MSFT', 'name': 'Microsoft Corporation', 'exchange': None, 'exchange_long': None, 'country': 'us', 'type': 'equity', 'industry': 'Technology', 'match_score': 13.695771, 'sentiment_score': 0.180767, 'highlights': [{'highlight': 'When <em>Microsoft</em>, Alphabet, Meta [+303 characters]', 'sentiment': 0.5423, 'highlighted_in': 'main_text'}, {'highlight': '<em>Microsoft</em> just announced plans [+265 characters]', 'sentiment': 0, 'highlighted_in': 'main_text'}, {'highlight': 'The hyperscalers (Amazon, <em>Microsoft<[+199 characters]', 'sentiment': 0, 'highlighted_in': 'main_text'}]}], 'similar': []}
# ------------------------------------
